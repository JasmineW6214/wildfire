# %%
# -*- coding: utf-8 -*-
"""filter_by_landcover&visualize.ipynb

Automatically generated by Colab.

Original file is located at
    https://colab.research.google.com/drive/113Y8RJxNuA8WmmX-NLkwQezlP6sk8uTz
"""

import pandas as pd
import ee
from google.colab import drive
import geemap

drive.mount('/content/drive')

# Define the path to the file in Google Drive
file_path = '/content/drive/My Drive/GEE_Exports/Alberta/2024/triple_merge-05.parquet'  # Adjust the path and file name as needed

# Load the CSV into a pandas DataFrame
df = pd.read_parquet(file_path)

# Filter the DataFrame
df_filter = df[
    ((df['LC_Type1']) < 10) & ((df['LW']) == 2)
]

# Define output path in Google Drive
output_path = '/content/drive/My Drive/GEE_Exports/Alberta/2024/landcover_filtered_merged-05.parquet'  # Adjust path if needed
df_filter.to_parquet(output_path, index=False)


print(f"Filtered data saved to: {output_path}")
print(f"Number of records before filtering: {len(df)}")
print(f"Number of records after filtering: {len(df_filter)}")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Alberta Bounding Box: {'geodesic': False, 'type': 'Polygon', 'coordinates': [[[-120.00029535835606, 48.995358253336285], [-109.9998561215751, 48.995358253336285], [-109.9998561215751, 60.000071881039275], [-120.00029535835606, 60.000071881039275], [-120.00029535835606, 48.995358253336285]]]}
# Longitude Range: -120.00029535835606 to -109.9998561215751
# Latitude Range: 48.995358253336285 to 60.000071881039275
